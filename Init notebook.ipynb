# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Requirement already satisfied: ipywidgets in /root/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 1)) (8.0.2)
# Requirement already satisfied: ipyvolume in /root/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: xlrd in /root/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: ase==3.21.1 in /root/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 4)) (3.21.1)
# Requirement already satisfied: qml in /root/venv/lib/python3.7/site-packages (from -r ./requirements.txt (line 5)) (0.4.0.27)
# Requirement already satisfied: widgetsnbextension~=4.0 in /root/venv/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: ipython>=6.1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 1)) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 1)) (6.16.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /root/venv/lib/python3.7/site-packages (from ipywidgets->-r ./requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: Pillow in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ipyvolume->-r ./requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: numpy in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ipyvolume->-r ./requirements.txt (line 2)) (1.21.6)
# Requirement already satisfied: ipywebrtc in /root/venv/lib/python3.7/site-packages (from ipyvolume->-r ./requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ipyvolume->-r ./requirements.txt (line 2)) (2.28.1)
# Requirement already satisfied: traittypes in /root/venv/lib/python3.7/site-packages (from ipyvolume->-r ./requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: pythreejs>=1.0.0 in /root/venv/lib/python3.7/site-packages (from ipyvolume->-r ./requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: scipy>=0.18.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ase==3.21.1->-r ./requirements.txt (line 4)) (1.7.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from ase==3.21.1->-r ./requirements.txt (line 4)) (3.5.3)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (0.17.2)
# Requirement already satisfied: decorator in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: pygments in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: backcall in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: pickleshare in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /root/venv/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (47.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (3.0.31)
# Requirement already satisfied: psutil in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (5.9.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (7.4.3)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (6.2)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (24.0.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (1.5.6)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->ipyvolume->-r ./requirements.txt (line 2)) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->ipyvolume->-r ./requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->ipyvolume->-r ./requirements.txt (line 2)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->ipyvolume->-r ./requirements.txt (line 2)) (3.4)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in /root/venv/lib/python3.7/site-packages (from pythreejs>=1.0.0->ipyvolume->-r ./requirements.txt (line 2)) (4.3.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=2.0.0->ase==3.21.1->-r ./requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=2.0.0->ase==3.21.1->-r ./requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=2.0.0->ase==3.21.1->-r ./requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib>=2.0.0->ase==3.21.1->-r ./requirements.txt (line 4)) (4.37.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from matplotlib>=2.0.0->ase==3.21.1->-r ./requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: entrypoints in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 1)) (4.11.2)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.0.0->ase==3.21.1->-r ./requirements.txt (line 4)) (4.4.0)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->ase==3.21.1->-r ./requirements.txt (line 4)) (1.16.0)
# WARNING: You are using pip version 20.1.1; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fc3d2631-9178-4bf3-9db3-87923c482dce' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
